# %%
import numpy as np # linear algebra
import pandas as pd

# %%
sad = pd.read_csv('/Users/Faaiz Anwar/Downloads/Emotion(sad).csv')
happy= pd.read_csv('/Users/Faaiz Anwar/Downloads/Emotion(happy).csv')
angry=pd.read_csv('/Users/Faaiz Anwar/Downloads/Emotion(angry).csv')

# %%
sad.shape
# Out:
# (635, 2)

# %%
happy.shape
# Out:
# (708, 2)

# %%
angry.shape
# Out:
# (696, 2)

# %%
sad = sad.drop_duplicates(subset='content', keep="first")

# %%
happy = happy.drop_duplicates(subset='content', keep="first")

# %%
angry = angry.drop_duplicates(subset='content', keep="first")

# %%
frames = [sad, happy, angry]
df = pd.concat(frames)

# %%
df.head()
# Out:
#                                              content sentiment
# 0  Never hurt people who love you a lot, because ...       sad
# 1  Don’t expect me to tell you what you did wrong...       sad
# 2  I preferred walking away than fighting for you...       sad
# 3  Moving forward in life isn’t the hard part, it...       sad
# 4  Never cry for anyone in your life, because tho...       sad

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                content sentiment
# 0    Never hurt people who love you a lot, because ...       sad
# 1    Don’t expect me to tell you what you did wrong...       sad
# 2    I preferred walking away than fighting for you...       sad
# 3    Moving forward in life isn’t the hard part, it...       sad
# 4    Never cry for anyone in your life, because tho...       sad
# ..                                                 ...       ...
# 681  The embarrassment after the anger is the bigge...     angry
# 685  The strong man is not the good wrestler; the s...     angry
# 687  A man is about as big as the things that make ...     angry
# 693  Is singing, if you’re angry & you know it punc...     angry
# 694  Telling someone to calm down just makes them s...     angry
#
# [1592 rows x 2 columns]>

# %%
df.shape
# Out:
# (1592, 2)

# %%
df = df.drop_duplicates(subset='content', keep="first")

# %%
df.shape
# Out:
# (1586, 2)

# %%
df['sentiment'].value_counts()
# Out:
# happy    702
# angry    494
# sad      390
# Name: sentiment, dtype: int64

# %%
df['sentiment'].replace({'happy':1,'angry':0,'sad':2},inplace=True)
# Out:
# C:\Users\Faaiz Anwar\Anaconda3\lib\site-packages\pandas\core\series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
df['sentiment'].value_counts()
# Out:
# 1    702
# 0    494
# 2    390
# Name: sentiment, dtype: int64

# %%
## cleaning html tag

import re
def clean_html(text):
    
    clean = re.compile('<.*?>')
    return re.sub(clean, '',text)
    
df['content']=df['content'].apply(clean_html)
# Out:
# <ipython-input-18-e5468934a03b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['content']=df['content'].apply(clean_html)

# %%
## converting to lower 

def convert_lower(text):
    return text.lower()

df['content']=df['content'].apply(convert_lower)
# Out:
# <ipython-input-19-b8ab131070a9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['content']=df['content'].apply(convert_lower)

# %%
def remove_special(text):
        x=''
        for i in text:
            if i.isalnum():
                x=x+i
            else:
                x=x+' '
        return x

df['content']=df['content'].apply(remove_special)
# Out:
# <ipython-input-20-49b05394e8b0>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['content']=df['content'].apply(remove_special)

# %%
import nltk
from nltk.corpus import stopwords

def remove_stopwords(text):
    x=[]
    for i in text.split():
        
        if i not in stopwords.words('english'):
            x.append(i)
    y=x[:]
    x.clear()
    return y
df['content']=df['content'].apply(remove_stopwords)
# Out:
# <ipython-input-21-70c0a829e7df>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['content']=df['content'].apply(remove_stopwords)

# %%
def join_back(list_input):
    return " ".join(list_input)
    

df['content']=df['content'].apply(join_back)
# Out:
# <ipython-input-22-b7ada01255ce>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['content']=df['content'].apply(join_back)

# %%
import nltk

from nltk.stem.porter import PorterStemmer
ps= PorterStemmer()
y=[]

def stem_words(text):
    for i in text:
        y.append(ps.stem(i))
    z=y[:]
    y.clear()
    return z
df['content']=df['content'].apply(stem_words)
# Out:
# <ipython-input-23-b8bb392a85cc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['content']=df['content'].apply(stem_words)

# %%
def joinback2(list_input):
    return "".join(list_input)
    


df['content']=df['content'].apply(joinback2)
# Out:
# <ipython-input-24-c1051da0e735>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['content']=df['content'].apply(joinback2)

# %%
df
# Out:
#                                                content  sentiment
# 0    never hurt people love lot hurt back probably ...          2
# 1    expect tell wrong figure ready correct cos kno...          2
# 2    preferred walking away fighting worth fighting...          2
# 3    moving forward life hard part leaving behind s...          2
# 4    never cry anyone life cry deserve tears deserv...          2
# ..                                                 ...        ...
# 681  embarrassment anger biggest humiliation person...          0
# 685  strong man good wrestler strong man one contro...          0
# 687                          man big things make angry          0
# 693                    singing angry know punches face          0
# 694            telling someone calm makes much angrier          0
#
# [1586 rows x 2 columns]

# %%
X=df['content']

# %%
X.shape
# Out:
# (1586,)

# %%
y=df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
X_test.shape
# Out:
# (476,)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=1500)

# %%
X_train = cv.fit_transform(X_train).toarray()
X_test=cv.transform(X_test).toarray()

# %% [markdown]
# CountVectorizer

# %% [markdown]
# CountVectorizer tokenizes(tokenization means breaking down a sentence or paragraph or any text into words) the text along with performing very basic preprocessing like removing the punctuation marks, converting all the words to lowercase

# %% [markdown]
# Scikit-learn provide three naive Bayes implementations: Bernoulli, multinomial and Gaussian. The only difference is about the probability distribution adopted. The first one is a binary algorithm particularly useful when a feature can be present or not. Multinomial naive Bayes assumes to have feature vector where each element represents the number of times it appears (or, very often, its frequency). This technique is very efficient in natural language processing or whenever the samples are composed starting from a common dictionary. The Gaussian Naive Bayes, instead, is based on a continuous distribution and it’s suitable for more generic classification tasks.

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
clf1=GaussianNB()
clf2=MultinomialNB()
clf3=BernoulliNB()

# %%
clf1.fit(X_train,y_train)
clf2.fit(X_train,y_train)
clf3.fit(X_train,y_train)
# Out:
# BernoulliNB()

# %%
y_pred1=clf1.predict(X_test)
y_pred2=clf2.predict(X_test)
y_pred3=clf3.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print("Gaussian",accuracy_score(y_test,y_pred1))
print("Multinomial",accuracy_score(y_test,y_pred2))
print("Bernaulli",accuracy_score(y_test,y_pred3))
# Out:
# Gaussian 0.5210084033613446
# Multinomial 0.707983193277311
# Bernaulli 0.6218487394957983

# %%
test="i am upset "
test = np.array([test])
test = cv.transform(test)

# %%
clf2.predict(test)
# Out:
# array([2], dtype=int64)

# %%
import numpy as np 
import pandas as pd
import os
from tqdm.notebook import tqdm
from tensorflow.keras import layers, models
import spacy as sp

# %%
nlp = sp.load('en_core_web_sm')

# %%
sad = pd.read_csv('/Users/Faaiz Anwar/Downloads/Emotion(sad).csv')
happy= pd.read_csv('/Users/Faaiz Anwar/Downloads/Emotion(happy).csv')
angry=pd.read_csv('/Users/Faaiz Anwar/Downloads/Emotion(angry).csv')
df1 = pd.concat([angry, happy, sad])
df1 = df1.reset_index(drop=True)

# %%
labellist = ["sad", "happy", "angry"]

parts = []
for label in labellist:
    part = df1[df1["sentiment"] == label].copy()
    sentiment = []
    for index in range(len(part.index)):
        if(part["sentiment"].iloc[index] == label):
            sentiment.append(1)
        else:
            sentiment.append(0)
    part[label] = sentiment
    parts.append(part)
df1 = pd.concat(parts, 0).drop("sentiment", 1).fillna(0)

# %%
df1
# Out:
#                                                 content  sad  happy  angry
# 1404  Never hurt people who love you a lot, because ...  1.0    0.0    0.0
# 1405  Don’t expect me to tell you what you did wrong...  1.0    0.0    0.0
# 1406  I preferred walking away than fighting for you...  1.0    0.0    0.0
# 1407  Moving forward in life isn’t the hard part, it...  1.0    0.0    0.0
# 1408  Never cry for anyone in your life, because tho...  1.0    0.0    0.0
# ...                                                 ...  ...    ...    ...
# 691              Is getting close to just walking away?  0.0    0.0    1.0
# 692   Did you ever just want to slap the stupid out ...  0.0    0.0    1.0
# 693   Is singing, if you’re angry & you know it punc...  0.0    0.0    1.0
# 694   Telling someone to calm down just makes them s...  0.0    0.0    1.0
# 695   Your mistake is letting me go, my mistake was ...  0.0    0.0    1.0
#
# [2039 rows x 4 columns]

# %%
def vectorize(texts):
    with nlp.disable_pipes():
        vectors = np.array(
            [
                nlp(texts[text_index]).vector
                for text_index in tqdm(range(len(texts)))
            ]
        )
    return vectors

# %%
def train(X_data, y_data, epochs = 50, batch_size = 8):
    model = models.Sequential()
    model.add(layers.Dense(300, activation = "relu", input_shape = (0,96)))
    model.add(layers.Dense(1200, activation = "relu"))
    model.add(layers.Dense(3, activation = "softmax"))
    model.compile(optimizer = "adam", metrics = ["accuracy"], loss = "categorical_crossentropy")
    model.fit(X_data, y_data, epochs = epochs, batch_size = batch_size, shuffle = True)
    return model

# %%
def predict(model, text, labellist = labellist):
    if(type(text) == list):
        pred = model.predict(nlp(text).vector)
    else:
        pred = model.predict(np.expand_dims(nlp(text).vector, 0))
    print("Predictions:\n" + "\n".join([labellist[x] + ": " + str(pred[0][x]) for x in range(len(pred[0]))]))

# %%
def evaluate(model, text, label, labellist = labellist):
    label = np.array(list(map(lambda x: (x==label)*1, labellist)))
    if(type(text) == list):
        loss, accuracy = model.evaluate(nlp(text).vector, label)
    else:
        loss, accuracy = model.evaluate(np.expand_dims(nlp(text).vector, 0), np.expand_dims(label, 0))
    print("Loss: %d" % loss)
    print("Accuracy: %d" % accuracy)

# %%
X_data = vectorize(df1["content"].str.lower().values)
y_data = df1[labellist]

# %%
model = train(X_data, y_data)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 0, 96) for input KerasTensor(type_spec=TensorSpec(shape=(None, 0, 96), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 96).
# WARNING:tensorflow:Model was constructed with shape (None, 0, 96) for input KerasTensor(type_spec=TensorSpec(shape=(None, 0, 96), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 96).
# 255/255 [==============================] - 2s 4ms/step - loss: 0.9908 - accuracy: 0.5223
# Epoch 2/50
# 255/255 [==============================] - 1s 4ms/step - loss: 0.7853 - accuracy: 0.6621
# Epoch 3/50
# 255/255 [==============================] - 1s 4ms/step - loss: 0.6262 - accuracy: 0.7308
# Epoch 4/50
# ...

# %%
predict(model, "i love code.")
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 0, 96) for input KerasTensor(type_spec=TensorSpec(shape=(None, 0, 96), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 96).
# Predictions:
# sad: 3.991281e-17
# happy: 1.0
# angry: 5.916648e-13

# %%
predict(model, "its sad to be alone")
# Out:
# Predictions:
# sad: 0.9998567
# happy: 0.00014321767
# angry: 9.4248595e-11

# %%
predict(model, "If you don't like me remember it's mind over matter, I don't mind and you don't matter.")
# Out:
# Predictions:
# sad: 0.0055046375
# happy: 0.006868111
# angry: 0.98762727

# %%
evaluate(model, "You are wonderful and gorgeous!", "happy")
# Out:
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0730 - accuracy: 1.0000
# Loss: 0
# Accuracy: 1
